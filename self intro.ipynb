# %% [markdown]
# <a href="https://colab.research.google.com/github/abhayayeee/abhayayeee/blob/main/self%20intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SELF INTRODUCTION
'''''
This is a simple python script for my self-introduction
escape sequences used
\n - for new line
\t - for tab space

'''''

print("\n\t╔══════════════════════════════════════════╗")
print("\t║           ✦ SELF INTRODUCTION ✦         ║")
print("\t╚══════════════════════════════════════════╝")

print("\n\tNAME              : ABHAY BIBEESH")
print("\tAGE               : 18")
print("\tJSOFT ID          : JSOFT26226")

print("\n\tSTUDYING AT       : JAIN UNIVERSITY KOCHI")
print("\tBATCH             : BCA APPLIED AI & DATA ANALYTICS")

print("\n\tINTERESTS         : GAMING, AI, CODING, DRAWING")
print("\tHOBBY             : GAMING")

print("\n\tPLACE             : KERALA, ALAPPUZHA")
print("\tCURRENTLY LIVING  : EDACHIRA")

print("\n\tGOAL              : \"TO BE A SKILLED AI DATA SCIENCE DEVELOPER\"")

print("\n\t" + "=" * 50)
print("\t\tTHANK YOU!")
print("\t" + "=" * 50)
# Out:
# 	╔══════════════════════════════════════════╗
# 	║           ✦ SELF INTRODUCTION ✦         ║
# 	╚══════════════════════════════════════════╝
#
# 	NAME              : ABHAY BIBEESH
# 	AGE               : 18
# 	JSOFT ID          : JSOFT26226
#
# 	STUDYING AT       : JAIN UNIVERSITY KOCHI
# 	BATCH             : BCA APPLIED AI & DATA ANALYTICS
#
# 	INTERESTS         : GAMING, AI, CODING, DRAWING
# 	HOBBY             : GAMING
#
# 	PLACE             : KERALA, ALAPPUZHA
# 	CURRENTLY LIVING  : EDACHIRA
#
# 	GOAL              : "TO BE A SKILLED AI DATA SCIENCE DEVELOPER"
#
# ...
# 		THANK YOU!
# ...
