# %% [markdown]
# <a href="https://colab.research.google.com/github/abhayayeee/abhayayeee/blob/main/hello_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# starting my first program
'''
this is the first program in Python
print hello world
'''
print("hello python")
# Out:
# hello python
